# %% [markdown]
# # Model Comparison
#
# I created 2 classes, one for the dataset, one for the model.
# These are the steps to run successfully the training, testing and prediction.
#
#  1. Load datasets
#  2. Apply transformations and feature engineering to the dataset (optional)
#      1. Choose variables to be used for training the model (optional)
#  4. Load model from SKLearn
#  5. Run the simple test
#
#  Below I created an example with the model that I had to test, Support Vector Machine.
#
#  The shape of the dataset is the following:
#
# 1. `'Family_Case_ID'`
# 2. `'Severity'`
# 3. `'Birthday_year'`
# 4. `'Parents or siblings infected'`
# 5. `'Wife/Husband or children infected'`
# 7. `'Medical_Expenses_Family'`
# 8. `'Medical_Tent_A'`
# 9. `'Medical_Tent_B'`
# 10. `'Medical_Tent_C'`
# 11. `'Medical_Tent_D'`
# 12. `'Medical_Tent_E'`
# 13. `'Medical_Tent_F'`
# 14. `'Medical_Tent_G'`
# 15. `'Medical_Tent_T'`
# 16. `'Medical_Tent_n/a'`
# 17. `'City_Albuquerque'`
# 18. `'City_Santa Fe'`
# 19. `'City_Taos'`
# 20. `'Gender_M'`
# 21. `'family_size'`
# 22. `'Sev_by_city'`: Average severity in the city of the patient.
# 23. `'Sev_by_tent'`: Average severity in the medical tent of the patient.
# 24. `'Sev_by_gender'`: Average severity whithin the gender of the patient.
# 25. `'Sev_family'`: Average severity in the family of the patient.
# 26. `'spending_vs_severity'`: Medical Expenses Family / Patient's Severity
# 27. `'spending_family_member'`: Medical Expenses Family / Number of cases in the family
# 28. `'severity_against_avg_city'`: Patient's Severity / Sev_by_city
# 29. `'severity_against_avg_tent'`: Patient's Severity / Sev_by_tent
# 30. `'severity_against_avg_gender'`: Patient's Severity / Sev_by_gender
# 31. `'spending_family_severity'`: Patient's Severity / Sev_family

# %%
from dataset import Dataset
from model import Model
import numpy as np

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import auc, accuracy_score, confusion_matrix, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold, RandomizedSearchCV, train_test_split

# %% [markdown]
# ## First model - Support Vector Machine - Alejandro

# %% [markdown]
# ### Step 1: Load datasets

# %%
def remove_IQR_outliers(df, n = 1.5): 
    Q1 = df.quantile(0.25)
    Q3 = df.quantile(0.75)
    IQR = Q3 - Q1

    mask = (df < (Q1 - n * IQR)) | (df > (Q3 + n * IQR))
    # exclude rotations 
    include_cols = ['Medical_Expenses_Family']
    for x in include_cols:
        mask.loc[:,~mask.columns.isin([x])] = False 
    df_out = df.copy()
    df_out[mask] = np.nan
    df_out.dropna(inplace = True)
    return df_out

# %%
dataset = Dataset()            # Loads the preprocessed dataset
train_set = dataset.train_data # Training set without labels (train.csv)
target = dataset.target        # Labels for training set     (train.csv[Deceased])
test_set = dataset.test_data   # Unlabeled test set          (test.csv)

train_set.describe()
# Out:
#        Family_Case_ID    Severity  Birthday_year  \
# count      898.000000  898.000000     898.000000
# mean     14286.119154    2.316258    1597.824053
# std      25443.036379    0.832842     792.720095
# min        345.000000    1.000000      -1.000000
# 25%       8195.000000    2.000000    1966.000000
# 50%      13587.500000    3.000000    1988.000000
# 75%      18891.000000    3.000000    1998.000000
# max     742836.000000    3.000000    2019.000000
#
#        Parents or siblings infected  Wife/Husband or children infected  \
# count                    898.000000                         898.000000
# mean                       0.380846                           0.522272
# std                        0.803941                           1.099333
# min                        0.000000                           0.000000
# 25%                        0.000000                           0.000000
# 50%                        0.000000                           0.000000
# 75%                        0.000000                           1.000000
# max                        6.000000                           8.000000
#
#        Medical_Expenses_Family  Sev_by_city  Sev_by_tent  Sev_by_gender  \
# count               898.000000   898.000000   898.000000     898.000000
# mean                892.749443     2.316258     2.316258       2.313653
# std                1385.917990     0.255180     0.615844       0.106050
# min                   0.000000     1.893491     1.000000       2.169811
# 25%                 221.000000     2.354391     2.623932       2.169811
# 50%                 405.000000     2.354391     2.623932       2.391753
# 75%                 857.750000     2.354391     2.623932       2.391753
# max               14345.000000     2.900000     3.000000       2.391753
#
#        Sev_family  ...  City_Santa Fe   City_Taos    Gender_M  family_size  \
# count  898.000000  ...     898.000000  898.000000  898.000000   898.000000
# mean     2.316258  ...       0.722717    0.089087    0.648107     1.826281
# std      0.825019  ...       0.447907    0.285028    0.477827     1.369723
# min      1.000000  ...       0.000000    0.000000    0.000000     1.000000
# 25%      2.000000  ...       0.000000    0.000000    0.000000     1.000000
# 50%      3.000000  ...       1.000000    0.000000    1.000000     1.000000
# 75%      3.000000  ...       1.000000    0.000000    1.000000     2.000000
# max      3.000000  ...       1.000000    1.000000    1.000000     7.000000
#
#        spending_vs_severity  spending_family_member  \
# count            898.000000              898.000000
# mean             692.063103              550.403471
# std             1428.606552              997.077121
# min                0.000000                0.000000
# 25%               73.666667              203.000000
# 50%              173.000000              228.000000
# 75%              573.000000              553.750000
# max            14345.000000            14345.000000
#
#        severity_against_avg_city  severity_against_avg_tent  \
# count                 898.000000                 898.000000
# mean                    1.000000                   1.000000
# std                     0.359305                   0.240359
# min                     0.344828                   0.381107
# 25%                     0.849476                   0.762215
# 50%                     1.034483                   1.143322
# 75%                     1.274215                   1.143322
# max                     1.584375                   2.898305
#
#        severity_against_avg_gender  spending_family_severity
# count                   898.000000                898.000000
# mean                      1.001201                430.066268
# std                       0.359250               1021.963995
# min                       0.418103                  0.000000
# 25%                       0.836207                 70.000000
# 50%                       1.254310                 81.000000
# 75%                       1.254310                343.000000
# max                       1.382609              14345.000000
#
# [8 rows x 30 columns]

# %% [markdown]
# ### Step 2: Apply transformations and select variables

# %%
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import RobustScaler, MinMaxScaler, StandardScaler


exclude_columns = [
    'Medical_Tent_T'
    
]

train_set = train_set.loc[:,~train_set.columns.isin(exclude_columns)]

# %%
#Scaling
scale_type = None
if scale_type == "RobustScaler":
    robust = RobustScaler().fit(train_set)
    train_set = robust.transform(train_set)
elif scale_type == "MinMaxScaler":
    minmax = MinMaxScaler().fit(train_set)
    train_set = minmax.transform(train_set)
elif scale_type == "StandardScaler":
    scaler = StandardScaler().fit(train_set)
    train_set = scaler.transform(train_set)

# %% [markdown]
# ### Step 3: Load model from SKLearn

# %%
import optuna
def objective(trial):

    loss = trial.suggest_categorical('loss', ["deviance", "exponential"])
    learning_rate = trial.suggest_float('learning_rate', 0.001, 0.5)
    n_estimators = trial.suggest_int('n_estimators', 50, 500)
    subsample = trial.suggest_float('subsample', 0.1, 1)
    criterion = trial.suggest_categorical('criterion', ['friedman_mse', 'mse', 'mae'])
    min_samples_split = trial.suggest_int('min_samples_split', 2, 100)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 2, 100)
    max_depth = trial.suggest_int('max_depth', 2, 20) 
    min_impurity_decrease = trial.suggest_float('min_impurity_decrease', 0., 0.1)
    max_features = trial.suggest_float('max_features', 0.1, 1)
    max_leaf_nodes = trial.suggest_categorical('max_leaf_nodes', [10, 50, 100, None])
    warm_start = trial.suggest_categorical('warm_start', [True, False])
    n_iter_no_change = trial.suggest_categorical('n_iter_no_change', [5, 10, 15, 20, None])
    ccp_alpha = trial.suggest_float('ccp_alpha', 0, 0.1)
    

                                                                
    clf = GradientBoostingClassifier(loss=loss,
                      learning_rate=learning_rate,
                        n_estimators=n_estimators,
                        subsample=subsample,
                        criterion=criterion,
                        min_samples_split=min_samples_split,
                        min_samples_leaf = min_samples_leaf,
                        max_depth=max_depth,
                        min_impurity_decrease = min_impurity_decrease,
                        max_features=max_features, 
                        max_leaf_nodes=max_leaf_nodes,
                        warm_start=warm_start,
                        n_iter_no_change=n_iter_no_change,
                        ccp_alpha=ccp_alpha,
                        validation_fraction = 0.2,
                        random_state=1234
                       )
    #print(clf)
    score = cross_val_score(clf, train_set, target, n_jobs=-1, cv=5, scoring="accuracy")
    # print(score)
    score = score.mean()
    return score

is_training = True
if is_training:
    study = optuna.create_study(direction='maximize')
    study.optimize(objective, n_trials=1000, n_jobs=-1)
# Out:
# [I 2020-05-23 11:12:26,344] Finished trial#4 with value: 0.6158100558659219 with parameters: {'loss': 'deviance', 'learning_rate': 0.1385970839374195, 'n_estimators': 128, 'subsample': 0.41207155079874913, 'criterion': 'mse', 'min_samples_split': 60, 'min_samples_leaf': 25, 'max_depth': 20, 'min_impurity_decrease': 0.0693861379672459, 'max_features': 0.5261930192037677, 'max_leaf_nodes': 10, 'warm_start': True, 'n_iter_no_change': 5, 'ccp_alpha': 0.09253577432790354}. Best is trial#4 with value: 0.6158100558659219.
# [I 2020-05-23 11:12:26,505] Finished trial#5 with value: 0.7849844816883924 with parameters: {'loss': 'deviance', 'learning_rate': 0.3775703008113848, 'n_estimators': 440, 'subsample': 0.9480922005020909, 'criterion': 'mse', 'min_samples_split': 19, 'min_samples_leaf': 11, 'max_depth': 19, 'min_impurity_decrease': 0.05745164862099518, 'max_features': 0.41554870322351967, 'max_leaf_nodes': 100, 'warm_start': False, 'n_iter_no_change': 15, 'ccp_alpha': 0.059034382169640465}. Best is trial#5 with value: 0.7849844816883924.
# [I 2020-05-23 11:12:26,569] Finished trial#2 with value: 0.7849844816883924 with parameters: {'loss': 'exponential', 'learning_rate': 0.4761743140920683, 'n_estimators': 97, 'subsample': 0.8597776684464151, 'criterion': 'friedman_mse', 'min_samples_split': 77, 'min_samples_leaf': 30, 'max_depth': 7, 'min_impurity_decrease': 0.03482146791933997, 'max_features': 0.262073701127606, 'max_leaf_nodes': 10, 'warm_start': False, 'n_iter_no_change': 5, 'ccp_alpha': 0.061307282917268585}. Best is trial#5 with value: 0.7849844816883924.
# [I 2020-05-23 11:12:26,786] Finished trial#7 with value: 0.6914897579143389 with parameters: {'loss': 'exponential', 'learning_rate': 0.20562208014158814, 'n_estimators': 333, 'subsample': 0.16529428715450967, 'criterion': 'mse', 'min_samples_split': 9, 'min_samples_leaf': 42, 'max_depth': 15, 'min_impurity_decrease': 0.03836548406748244, 'max_features': 0.9511053286521229, 'max_leaf_nodes': 10, 'warm_start': False, 'n_iter_no_change': 5, 'ccp_alpha': 0.08856464715644523}. Best is trial#5 with value: 0.7849844816883924.
# [I 2020-05-23 11:12:27,371] Finished trial#10 with value: 0.7849844816883924 with parameters: {'loss': 'exponential', 'learning_rate': 0.3640495812301672, 'n_estimators': 375, 'subsample': 0.9394177686099487, 'criterion': 'mse', 'min_samples_split': 81, 'min_samples_leaf': 81, 'max_depth': 14, 'min_impurity_decrease': 0.0765958888863443, 'max_features': 0.6179825508809804, 'max_leaf_nodes': 10, 'warm_start': False, 'n_iter_no_change': 5, 'ccp_alpha': 0.026741124450244614}. Best is trial#5 with value: 0.7849844816883924.
# [I 2020-05-23 11:12:29,095] Finished trial#1 with value: 0.6158100558659219 with parameters: {'loss': 'deviance', 'learning_rate': 0.012050773021225297, 'n_estimators': 86, 'subsample': 0.4197040551553035, 'criterion': 'friedman_mse', 'min_samples_split': 70, 'min_samples_leaf': 51, 'max_depth': 11, 'min_impurity_decrease': 0.08800985565618105, 'max_features': 0.6207819187129688, 'max_leaf_nodes': 100, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.058355747808836025}. Best is trial#5 with value: 0.7849844816883924.
# [I 2020-05-23 11:12:29,161] Finished trial#9 with value: 0.7849844816883924 with parameters: {'loss': 'deviance', 'learning_rate': 0.2079731672454885, 'n_estimators': 489, 'subsample': 0.8266015829724157, 'criterion': 'mae', 'min_samples_split': 37, 'min_samples_leaf': 88, 'max_depth': 11, 'min_impurity_decrease': 0.07982528600386538, 'max_features': 0.8861815566258063, 'max_leaf_nodes': 10, 'warm_start': True, 'n_iter_no_change': 10, 'ccp_alpha': 0.01265928333492198}. Best is trial#5 with value: 0.7849844816883924.
# [I 2020-05-23 11:12:30,597] Finished trial#8 with value: 0.7849844816883923 with parameters: {'loss': 'exponential', 'learning_rate': 0.37634509470443184, 'n_estimators': 343, 'subsample': 0.5381715747452185, 'criterion': 'mae', 'min_samples_split': 38, 'min_samples_leaf': 18, 'max_depth': 14, 'min_impurity_decrease': 0.0025953448290854555, 'max_features': 0.49434790299837805, 'max_leaf_nodes': 50, 'warm_start': False, 'n_iter_no_change': 15, 'ccp_alpha': 0.026570975603701898}. Best is trial#5 with value: 0.7849844816883924.
# [I 2020-05-23 11:12:31,176] Finished trial#11 with value: 0.7849844816883924 with parameters: {'loss': 'exponential', 'learning_rate': 0.2424945203989645, 'n_estimators': 125, 'subsample': 0.36786735041211427, 'criterion': 'mae', 'min_samples_split': 5, 'min_samples_leaf': 64, 'max_depth': 8, 'min_impurity_decrease': 0.046734884175222736, 'max_features': 0.6464629438749632, 'max_leaf_nodes': 100, 'warm_start': True, 'n_iter_no_change': 15, 'ccp_alpha': 0.05044975846439575}. Best is trial#5 with value: 0.7849844816883924.
# [I 2020-05-23 11:12:31,653] Finished trial#3 with value: 0.7849844816883924 with parameters: {'loss': 'deviance', 'learning_rate': 0.04553598491038054, 'n_estimators': 449, 'subsample': 0.26204356347566327, 'criterion': 'mae', 'min_samples_split': 89, 'min_samples_leaf': 31, 'max_depth': 14, 'min_impurity_decrease': 0.05858455463530801, 'max_features': 0.9759437443233819, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': 15, 'ccp_alpha': 0.020760400670618774}. Best is trial#5 with value: 0.7849844816883924.
# [I 2020-05-23 11:12:32,340] Finished trial#16 with value: 0.6158100558659219 with parameters: {'loss': 'deviance', 'learning_rate': 0.0956124178836806, 'n_estimators': 253, 'subsample': 0.8316701964414203, 'criterion': 'friedman_mse', 'min_samples_split': 20, 'min_samples_leaf': 100, 'max_depth': 14, 'min_impurity_decrease': 0.095884932006269, 'max_features': 0.2920899390992233, 'max_leaf_nodes': None, 'warm_start': False, 'n_iter_no_change': 10, 'ccp_alpha': 0.0795992397057872}. Best is trial#5 with value: 0.7849844816883924.
# [I 2020-05-23 11:12:32,621] Finished trial#15 with value: 0.6158100558659219 with parameters: {'loss': 'exponential', 'learning_rate': 0.4514763816135754, 'n_estimators': 407, 'subsample': 0.1317579857283034, 'criterion': 'mse', 'min_samples_split': 92, 'min_samples_leaf': 47, 'max_depth': 13, 'min_impurity_decrease': 0.012334020321094687, 'max_features': 0.12057842499542498, 'max_leaf_nodes': 10, 'warm_start': True, 'n_iter_no_change': 20, 'ccp_alpha': 0.061751375171360826}. Best is trial#5 with value: 0.7849844816883924.
# [I 2020-05-23 11:12:33,660] Finished trial#19 with value: 0.8017256362507759 with parameters: {'loss': 'exponential', 'learning_rate': 0.49447956206556704, 'n_estimators': 220, 'subsample': 0.708462907281078, 'criterion': 'friedman_mse', 'min_samples_split': 100, 'min_samples_leaf': 31, 'max_depth': 2, 'min_impurity_decrease': 0.030773178535190904, 'max_features': 0.17948686496535765, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': 5, 'ccp_alpha': 0.0022264049243038084}. Best is trial#19 with value: 0.8017256362507759.
# [I 2020-05-23 11:12:34,040] Finished trial#12 with value: 0.6672067039106145 with parameters: {'loss': 'deviance', 'learning_rate': 0.2970635191638656, 'n_estimators': 140, 'subsample': 0.6402176917870858, 'criterion': 'friedman_mse', 'min_samples_split': 79, 'min_samples_leaf': 50, 'max_depth': 18, 'min_impurity_decrease': 0.04511474611632987, 'max_features': 0.7507696258108938, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.04864897085228259}. Best is trial#19 with value: 0.8017256362507759.
# [I 2020-05-23 11:12:34,557] Finished trial#18 with value: 0.6158100558659219 with parameters: {'loss': 'exponential', 'learning_rate': 0.4924036630037761, 'n_estimators': 202, 'subsample': 0.1361680734767444, 'criterion': 'friedman_mse', 'min_samples_split': 95, 'min_samples_leaf': 31, 'max_depth': 3, 'min_impurity_decrease': 0.026933454713162802, 'max_features': 0.1233730780667012, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': 20, 'ccp_alpha': 0.0028215549758039866}. Best is trial#19 with value: 0.8017256362507759.
# [I 2020-05-23 11:12:34,735] Finished trial#20 with value: 0.7805462445685909 with parameters: {'loss': 'exponential', 'learning_rate': 0.491151917533085, 'n_estimators': 210, 'subsample': 0.6894215277796091, 'criterion': 'friedman_mse', 'min_samples_split': 75, 'min_samples_leaf': 4, 'max_depth': 2, 'min_impurity_decrease': 0.025614541014175506, 'max_features': 0.12644466929365936, 'max_leaf_nodes': 50, 'warm_start': False, 'n_iter_no_change': 5, 'ccp_alpha': 0.03924073711135005}. Best is trial#19 with value: 0.8017256362507759.
# [I 2020-05-23 11:12:34,905] Finished trial#17 with value: 0.7827870887647425 with parameters: {'loss': 'exponential', 'learning_rate': 0.48514496598667356, 'n_estimators': 214, 'subsample': 0.7392365092804276, 'criterion': 'friedman_mse', 'min_samples_split': 100, 'min_samples_leaf': 4, 'max_depth': 2, 'min_impurity_decrease': 0.016921126960015714, 'max_features': 0.1741113991417696, 'max_leaf_nodes': None, 'warm_start': False, 'n_iter_no_change': 20, 'ccp_alpha': 0.07475589256841425}. Best is trial#19 with value: 0.8017256362507759.
# [I 2020-05-23 11:12:35,476] Finished trial#24 with value: 0.7849844816883924 with parameters: {'loss': 'exponential', 'learning_rate': 0.39901932616871644, 'n_estimators': 324, 'subsample': 0.9990528286659875, 'criterion': 'mse', 'min_samples_split': 58, 'min_samples_leaf': 71, 'max_depth': 7, 'min_impurity_decrease': 0.07187875574706279, 'max_features': 0.775516361477645, 'max_leaf_nodes': 50, 'warm_start': False, 'n_iter_no_change': 5, 'ccp_alpha': 0.00021310666597183303}. Best is trial#19 with value: 0.8017256362507759.
# [I 2020-05-23 11:12:35,587] Finished trial#23 with value: 0.7772129112352576 with parameters: {'loss': 'exponential', 'learning_rate': 0.4353270620118709, 'n_estimators': 52, 'subsample': 0.7826566048210206, 'criterion': 'friedman_mse', 'min_samples_split': 100, 'min_samples_leaf': 2, 'max_depth': 6, 'min_impurity_decrease': 0.027566069582857206, 'max_features': 0.28178030655061753, 'max_leaf_nodes': 50, 'warm_start': False, 'n_iter_no_change': 5, 'ccp_alpha': 0.07455195324693419}. Best is trial#19 with value: 0.8017256362507759.
# [I 2020-05-23 11:12:35,661] Finished trial#22 with value: 0.7772067039106145 with parameters: {'loss': 'exponential', 'learning_rate': 0.4866613959044841, 'n_estimators': 59, 'subsample': 0.6962023635532878, 'criterion': 'friedman_mse', 'min_samples_split': 98, 'min_samples_leaf': 2, 'max_depth': 2, 'min_impurity_decrease': 0.023454487241897685, 'max_features': 0.28660967391266434, 'max_leaf_nodes': 50, 'warm_start': False, 'n_iter_no_change': 5, 'ccp_alpha': 0.0744331366953974}. Best is trial#19 with value: 0.8017256362507759.
# [I 2020-05-23 11:12:35,874] Finished trial#21 with value: 0.8139602731222843 with parameters: {'loss': 'exponential', 'learning_rate': 0.49938898967877837, 'n_estimators': 220, 'subsample': 0.6846216643417838, 'criterion': 'friedman_mse', 'min_samples_split': 99, 'min_samples_leaf': 3, 'max_depth': 2, 'min_impurity_decrease': 0.03124066995751137, 'max_features': 0.10089465659931851, 'max_leaf_nodes': 50, 'warm_start': False, 'n_iter_no_change': 5, 'ccp_alpha': 0.0032684717126762147}. Best is trial#21 with value: 0.8139602731222843.
# [I 2020-05-23 11:12:36,902] Finished trial#28 with value: 0.7849844816883924 with parameters: {'loss': 'exponential', 'learning_rate': 0.40769200163916763, 'n_estimators': 289, 'subsample': 0.5405073069672476, 'criterion': 'mse', 'min_samples_split': 58, 'min_samples_leaf': 73, 'max_depth': 5, 'min_impurity_decrease': 0.05879903527303207, 'max_features': 0.7886130147992434, 'max_leaf_nodes': 50, 'warm_start': False, 'n_iter_no_change': 5, 'ccp_alpha': 0.0006104843723072145}. Best is trial#21 with value: 0.8139602731222843.
# [I 2020-05-23 11:12:37,107] Finished trial#14 with value: 0.7849844816883924 with parameters: {'loss': 'exponential', 'learning_rate': 0.01380869070622091, 'n_estimators': 231, 'subsample': 0.7476934225417157, 'criterion': 'friedman_mse', 'min_samples_split': 78, 'min_samples_leaf': 53, 'max_depth': 7, 'min_impurity_decrease': 0.025838263173671105, 'max_features': 0.8688410701269527, 'max_leaf_nodes': None, 'warm_start': False, 'n_iter_no_change': 10, 'ccp_alpha': 0.06651842810302354}. Best is trial#21 with value: 0.8139602731222843.
# [I 2020-05-23 11:12:37,381] Finished trial#27 with value: 0.7849844816883924 with parameters: {'loss': 'exponential', 'learning_rate': 0.300836795524412, 'n_estimators': 167, 'subsample': 0.4843038998467292, 'criterion': 'mae', 'min_samples_split': 2, 'min_samples_leaf': 65, 'max_depth': 5, 'min_impurity_decrease': 0.06018743511454739, 'max_features': 0.7902705346097162, 'max_leaf_nodes': 50, 'warm_start': False, 'n_iter_no_change': 5, 'ccp_alpha': 0.0018213037465214003}. Best is trial#21 with value: 0.8139602731222843.
# [I 2020-05-23 11:12:37,662] Finished trial#26 with value: 0.7849844816883924 with parameters: {'loss': 'exponential', 'learning_rate': 0.2508394847312565, 'n_estimators': 159, 'subsample': 0.5300440240093242, 'criterion': 'mae', 'min_samples_split': 5, 'min_samples_leaf': 62, 'max_depth': 5, 'min_impurity_decrease': 0.05187063759116546, 'max_features': 0.8505543463759042, 'max_leaf_nodes': 50, 'warm_start': False, 'n_iter_no_change': 5, 'ccp_alpha': 0.0028434369272959856}. Best is trial#21 with value: 0.8139602731222843.
# [I 2020-05-23 11:12:38,131] Finished trial#13 with value: 0.809528243327126 with parameters: {'loss': 'exponential', 'learning_rate': 0.28540395695839815, 'n_estimators': 180, 'subsample': 0.8992435483713533, 'criterion': 'friedman_mse', 'min_samples_split': 60, 'min_samples_leaf': 16, 'max_depth': 15, 'min_impurity_decrease': 0.09654765266315402, 'max_features': 0.8567266789928557, 'max_leaf_nodes': 50, 'warm_start': False, 'n_iter_no_change': None, 'ccp_alpha': 0.010608016406436572}. Best is trial#21 with value: 0.8139602731222843.
# [I 2020-05-23 11:12:38,500] Finished trial#29 with value: 0.7872067039106146 with parameters: {'loss': 'exponential', 'learning_rate': 0.31919654845095463, 'n_estimators': 287, 'subsample': 0.5852532486931145, 'criterion': 'friedman_mse', 'min_samples_split': 43, 'min_samples_leaf': 71, 'max_depth': 4, 'min_impurity_decrease': 0.05683015507463117, 'max_features': 0.4192712245959, 'max_leaf_nodes': 50, 'warm_start': False, 'n_iter_no_change': 5, 'ccp_alpha': 0.008596243135440948}. Best is trial#21 with value: 0.8139602731222843.
# [I 2020-05-23 11:12:38,767] Finished trial#32 with value: 0.7872067039106146 with parameters: {'loss': 'exponential', 'learning_rate': 0.42332612090699717, 'n_estimators': 286, 'subsample': 0.5958718435708483, 'criterion': 'mse', 'min_samples_split': 43, 'min_samples_leaf': 84, 'max_depth': 4, 'min_impurity_decrease': 0.0008769398810092068, 'max_features': 0.3943951555344171, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': 5, 'ccp_alpha': 0.013602537271050548}. Best is trial#21 with value: 0.8139602731222843.
# [I 2020-05-23 11:12:40,218] Finished trial#30 with value: 0.7883054003724396 with parameters: {'loss': 'exponential', 'learning_rate': 0.31034782295144525, 'n_estimators': 172, 'subsample': 0.6006641546667387, 'criterion': 'friedman_mse', 'min_samples_split': 87, 'min_samples_leaf': 61, 'max_depth': 4, 'min_impurity_decrease': 0.002815804543874801, 'max_features': 0.372843134676045, 'max_leaf_nodes': None, 'warm_start': False, 'n_iter_no_change': 10, 'ccp_alpha': 0.01625615343638438}. Best is trial#21 with value: 0.8139602731222843.
# [I 2020-05-23 11:12:40,589] Finished trial#25 with value: 0.7849844816883924 with parameters: {'loss': 'exponential', 'learning_rate': 0.31378611715102384, 'n_estimators': 166, 'subsample': 0.5065300845373568, 'criterion': 'mae', 'min_samples_split': 37, 'min_samples_leaf': 63, 'max_depth': 5, 'min_impurity_decrease': 0.04851473731008916, 'max_features': 0.7064695002045434, 'max_leaf_nodes': 100, 'warm_start': True, 'n_iter_no_change': 15, 'ccp_alpha': 0.040982576760847836}. Best is trial#21 with value: 0.8139602731222843.
# [I 2020-05-23 11:12:41,062] Finished trial#31 with value: 0.7938919925512103 with parameters: {'loss': 'exponential', 'learning_rate': 0.3274957053509116, 'n_estimators': 260, 'subsample': 0.6173521575518839, 'criterion': 'friedman_mse', 'min_samples_split': 88, 'min_samples_leaf': 40, 'max_depth': 4, 'min_impurity_decrease': 0.0006936219543619872, 'max_features': 0.2020486359795759, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': 10, 'ccp_alpha': 0.011814931318563843}. Best is trial#21 with value: 0.8139602731222843.
# [I 2020-05-23 11:12:44,983] Finished trial#34 with value: 0.7983860955927995 with parameters: {'loss': 'exponential', 'learning_rate': 0.33858929164273494, 'n_estimators': 187, 'subsample': 0.6384711413519392, 'criterion': 'friedman_mse', 'min_samples_split': 85, 'min_samples_leaf': 15, 'max_depth': 17, 'min_impurity_decrease': 0.008285348886160726, 'max_features': 0.20678194981779421, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.015307748063607338}. Best is trial#21 with value: 0.8139602731222843.
# [I 2020-05-23 11:12:46,180] Finished trial#0 with value: 0.7849844816883924 with parameters: {'loss': 'exponential', 'learning_rate': 0.03926842780626239, 'n_estimators': 455, 'subsample': 0.7835174877257756, 'criterion': 'mse', 'min_samples_split': 34, 'min_samples_leaf': 94, 'max_depth': 2, 'min_impurity_decrease': 0.09550478075885324, 'max_features': 0.7101620359875422, 'max_leaf_nodes': 10, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.010080077008418387}. Best is trial#21 with value: 0.8139602731222843.
# [I 2020-05-23 11:12:46,454] Finished trial#35 with value: 0.800633147113594 with parameters: {'loss': 'exponential', 'learning_rate': 0.34076837810104843, 'n_estimators': 179, 'subsample': 0.8956915659782564, 'criterion': 'friedman_mse', 'min_samples_split': 88, 'min_samples_leaf': 15, 'max_depth': 17, 'min_impurity_decrease': 0.038547427441241414, 'max_features': 0.20259527102251826, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.0207589540369906}. Best is trial#21 with value: 0.8139602731222843.
# [I 2020-05-23 11:12:48,639] Finished trial#33 with value: 0.8162073246430788 with parameters: {'loss': 'exponential', 'learning_rate': 0.325911432600638, 'n_estimators': 281, 'subsample': 0.6026178019066932, 'criterion': 'friedman_mse', 'min_samples_split': 45, 'min_samples_leaf': 15, 'max_depth': 17, 'min_impurity_decrease': 0.004690658296891359, 'max_features': 0.4214085177659265, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.011578849488663895}. Best is trial#33 with value: 0.8162073246430788.
# [I 2020-05-23 11:12:50,786] Finished trial#36 with value: 0.7849844816883924 with parameters: {'loss': 'exponential', 'learning_rate': 0.14722315086275325, 'n_estimators': 246, 'subsample': 0.8855424451098386, 'criterion': 'friedman_mse', 'min_samples_split': 69, 'min_samples_leaf': 14, 'max_depth': 17, 'min_impurity_decrease': 0.03570538341873141, 'max_features': 0.20182556477689628, 'max_leaf_nodes': 100, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.03626852238659481}. Best is trial#33 with value: 0.8162073246430788.
# [I 2020-05-23 11:12:51,594] Finished trial#37 with value: 0.7883240223463688 with parameters: {'loss': 'exponential', 'learning_rate': 0.3495772520029641, 'n_estimators': 253, 'subsample': 0.9044317975582793, 'criterion': 'friedman_mse', 'min_samples_split': 67, 'min_samples_leaf': 14, 'max_depth': 17, 'min_impurity_decrease': 0.03641061971125708, 'max_features': 0.20897825150358346, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.026267273461588338}. Best is trial#33 with value: 0.8162073246430788.
# [I 2020-05-23 11:12:52,739] Finished trial#6 with value: 0.7849844816883924 with parameters: {'loss': 'deviance', 'learning_rate': 0.1008782557648693, 'n_estimators': 338, 'subsample': 0.9020816239296695, 'criterion': 'mae', 'min_samples_split': 44, 'min_samples_leaf': 41, 'max_depth': 6, 'min_impurity_decrease': 0.00050311846384129, 'max_features': 0.9649741482202958, 'max_leaf_nodes': 50, 'warm_start': False, 'n_iter_no_change': None, 'ccp_alpha': 0.07437801650889188}. Best is trial#33 with value: 0.8162073246430788.
# [I 2020-05-23 11:12:54,005] Finished trial#38 with value: 0.8139664804469273 with parameters: {'loss': 'exponential', 'learning_rate': 0.3444079130515151, 'n_estimators': 251, 'subsample': 0.6648663229777958, 'criterion': 'friedman_mse', 'min_samples_split': 86, 'min_samples_leaf': 16, 'max_depth': 17, 'min_impurity_decrease': 0.010279293728232837, 'max_features': 0.19657432058711602, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.008427461401956333}. Best is trial#33 with value: 0.8162073246430788.
# [I 2020-05-23 11:12:54,495] Finished trial#43 with value: 0.810626939788951 with parameters: {'loss': 'exponential', 'learning_rate': 0.4562766545265324, 'n_estimators': 97, 'subsample': 0.6953720829280873, 'criterion': 'friedman_mse', 'min_samples_split': 26, 'min_samples_leaf': 23, 'max_depth': 12, 'min_impurity_decrease': 0.015341716802805189, 'max_features': 0.34293040790141854, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.008613394734594342}. Best is trial#33 with value: 0.8162073246430788.
# [I 2020-05-23 11:12:54,816] Finished trial#40 with value: 0.7939106145251398 with parameters: {'loss': 'exponential', 'learning_rate': 0.24665860534587775, 'n_estimators': 200, 'subsample': 0.8783606595746087, 'criterion': 'friedman_mse', 'min_samples_split': 71, 'min_samples_leaf': 18, 'max_depth': 17, 'min_impurity_decrease': 0.035399284441854195, 'max_features': 0.20965996648626745, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.02089964003996553}. Best is trial#33 with value: 0.8162073246430788.
# [I 2020-05-23 11:12:55,216] Finished trial#39 with value: 0.7916759776536313 with parameters: {'loss': 'exponential', 'learning_rate': 0.265328637899712, 'n_estimators': 236, 'subsample': 0.9072178762782361, 'criterion': 'friedman_mse', 'min_samples_split': 71, 'min_samples_leaf': 17, 'max_depth': 17, 'min_impurity_decrease': 0.012676043093237273, 'max_features': 0.21257035788337197, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.02187034776751508}. Best is trial#33 with value: 0.8162073246430788.
# [I 2020-05-23 11:12:56,339] Finished trial#41 with value: 0.7949720670391061 with parameters: {'loss': 'exponential', 'learning_rate': 0.27252132260303336, 'n_estimators': 234, 'subsample': 0.8682242729819898, 'criterion': 'friedman_mse', 'min_samples_split': 69, 'min_samples_leaf': 23, 'max_depth': 17, 'min_impurity_decrease': 0.0362333380248961, 'max_features': 0.1691965979760026, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.022410981412560267}. Best is trial#33 with value: 0.8162073246430788.
# [I 2020-05-23 11:12:56,926] Finished trial#45 with value: 0.8083985102420858 with parameters: {'loss': 'exponential', 'learning_rate': 0.2594366446353396, 'n_estimators': 99, 'subsample': 0.4682803589796465, 'criterion': 'friedman_mse', 'min_samples_split': 51, 'min_samples_leaf': 23, 'max_depth': 12, 'min_impurity_decrease': 0.018253525607705434, 'max_features': 0.34369748700502545, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.008917756415733053}. Best is trial#33 with value: 0.8162073246430788.
# [I 2020-05-23 11:12:59,264] Finished trial#48 with value: 0.8095716945996276 with parameters: {'loss': 'exponential', 'learning_rate': 0.45543488329242887, 'n_estimators': 81, 'subsample': 0.45998989739523777, 'criterion': 'friedman_mse', 'min_samples_split': 27, 'min_samples_leaf': 25, 'max_depth': 12, 'min_impurity_decrease': 0.018440492867729624, 'max_features': 0.34055271508613205, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.007618317688099364}. Best is trial#33 with value: 0.8162073246430788.
# [I 2020-05-23 11:12:59,775] Finished trial#42 with value: 0.8150962135319677 with parameters: {'loss': 'exponential', 'learning_rate': 0.25099447550675485, 'n_estimators': 251, 'subsample': 0.6979752621525248, 'criterion': 'friedman_mse', 'min_samples_split': 65, 'min_samples_leaf': 22, 'max_depth': 16, 'min_impurity_decrease': 0.017955162382518264, 'max_features': 0.4740815475993885, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.00807096681590506}. Best is trial#33 with value: 0.8162073246430788.
# [I 2020-05-23 11:13:00,151] Finished trial#49 with value: 0.8151024208566108 with parameters: {'loss': 'exponential', 'learning_rate': 0.28293291751774835, 'n_estimators': 91, 'subsample': 0.4591465767995013, 'criterion': 'friedman_mse', 'min_samples_split': 26, 'min_samples_leaf': 24, 'max_depth': 12, 'min_impurity_decrease': 0.01636829445649353, 'max_features': 0.3516190501681802, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.007137019111985599}. Best is trial#33 with value: 0.8162073246430788.
# [I 2020-05-23 11:13:00,272] Finished trial#47 with value: 0.8195592799503414 with parameters: {'loss': 'exponential', 'learning_rate': 0.45739682491043404, 'n_estimators': 107, 'subsample': 0.6522088482784741, 'criterion': 'friedman_mse', 'min_samples_split': 18, 'min_samples_leaf': 24, 'max_depth': 10, 'min_impurity_decrease': 0.018026635380566567, 'max_features': 0.46773451650722747, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.0063819247890430485}. Best is trial#47 with value: 0.8195592799503414.
# [I 2020-05-23 11:13:01,367] Finished trial#50 with value: 0.8229174425822471 with parameters: {'loss': 'exponential', 'learning_rate': 0.46408129914410523, 'n_estimators': 96, 'subsample': 0.4691333694384585, 'criterion': 'friedman_mse', 'min_samples_split': 50, 'min_samples_leaf': 8, 'max_depth': 12, 'min_impurity_decrease': 0.01930573587447156, 'max_features': 0.3373741976866363, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.00863387277371251}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:02,665] Finished trial#44 with value: 0.806219739292365 with parameters: {'loss': 'exponential', 'learning_rate': 0.2596207053243419, 'n_estimators': 303, 'subsample': 0.4582623101644897, 'criterion': 'friedman_mse', 'min_samples_split': 47, 'min_samples_leaf': 23, 'max_depth': 20, 'min_impurity_decrease': 0.08876282588958459, 'max_features': 0.3290138632495752, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.008031071953758531}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:03,969] Finished trial#52 with value: 0.786145251396648 with parameters: {'loss': 'exponential', 'learning_rate': 0.4616473906411333, 'n_estimators': 74, 'subsample': 0.3567726573823479, 'criterion': 'friedman_mse', 'min_samples_split': 25, 'min_samples_leaf': 8, 'max_depth': 10, 'min_impurity_decrease': 0.006380216085528058, 'max_features': 0.47581094885916386, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.006688541376002717}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:06,336] Finished trial#56 with value: 0.7794289261328369 with parameters: {'loss': 'deviance', 'learning_rate': 0.21316537593247525, 'n_estimators': 116, 'subsample': 0.3387751891054019, 'criterion': 'friedman_mse', 'min_samples_split': 11, 'min_samples_leaf': 8, 'max_depth': 9, 'min_impurity_decrease': 0.0052780901493552895, 'max_features': 0.47716862730115145, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.03123854993495605}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:07,995] Finished trial#57 with value: 0.7849844816883924 with parameters: {'loss': 'deviance', 'learning_rate': 0.22015627346436342, 'n_estimators': 130, 'subsample': 0.3628782408423978, 'criterion': 'friedman_mse', 'min_samples_split': 13, 'min_samples_leaf': 9, 'max_depth': 9, 'min_impurity_decrease': 0.005971270557008929, 'max_features': 0.5015470187871138, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.029804075906813186}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:09,612] Finished trial#58 with value: 0.7849844816883924 with parameters: {'loss': 'deviance', 'learning_rate': 0.19799719417021894, 'n_estimators': 132, 'subsample': 0.39041915856164827, 'criterion': 'friedman_mse', 'min_samples_split': 14, 'min_samples_leaf': 7, 'max_depth': 10, 'min_impurity_decrease': 0.008723049479639904, 'max_features': 0.5677504537958872, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.01902697932066581}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:10,091] Finished trial#46 with value: 0.8084357541899442 with parameters: {'loss': 'exponential', 'learning_rate': 0.268515977477672, 'n_estimators': 319, 'subsample': 0.31141153139809985, 'criterion': 'friedman_mse', 'min_samples_split': 51, 'min_samples_leaf': 25, 'max_depth': 20, 'min_impurity_decrease': 0.01963866205371286, 'max_features': 0.5091125808422095, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.006888170078578226}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:12,740] Finished trial#55 with value: 0.7849844816883924 with parameters: {'loss': 'deviance', 'learning_rate': 0.2110738889351015, 'n_estimators': 311, 'subsample': 0.6584826740069247, 'criterion': 'friedman_mse', 'min_samples_split': 12, 'min_samples_leaf': 35, 'max_depth': 9, 'min_impurity_decrease': 0.007051634371890006, 'max_features': 0.4743893524991331, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.017504426978791406}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:14,054] Finished trial#54 with value: 0.7771942892613283 with parameters: {'loss': 'deviance', 'learning_rate': 0.21663811615170397, 'n_estimators': 311, 'subsample': 0.37587632882750094, 'criterion': 'friedman_mse', 'min_samples_split': 15, 'min_samples_leaf': 9, 'max_depth': 9, 'min_impurity_decrease': 0.00760021526395456, 'max_features': 0.484109404484178, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.016421218857907212}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:14,222] Finished trial#60 with value: 0.8050279329608939 with parameters: {'loss': 'exponential', 'learning_rate': 0.16841591214625956, 'n_estimators': 149, 'subsample': 0.6510777207644511, 'criterion': 'friedman_mse', 'min_samples_split': 32, 'min_samples_leaf': 37, 'max_depth': 15, 'min_impurity_decrease': 0.02144776092373236, 'max_features': 0.5589931135297218, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.016084477380197262}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:14,527] Finished trial#53 with value: 0.8005896958410925 with parameters: {'loss': 'deviance', 'learning_rate': 0.20532392005099154, 'n_estimators': 307, 'subsample': 0.6731950043577095, 'criterion': 'friedman_mse', 'min_samples_split': 25, 'min_samples_leaf': 8, 'max_depth': 20, 'min_impurity_decrease': 0.00804066383584866, 'max_features': 0.45649968584859857, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.006961458167824414}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:15,252] Finished trial#51 with value: 0.8061949099937926 with parameters: {'loss': 'exponential', 'learning_rate': 0.4496107590057234, 'n_estimators': 315, 'subsample': 0.7745591283655238, 'criterion': 'friedman_mse', 'min_samples_split': 26, 'min_samples_leaf': 8, 'max_depth': 9, 'min_impurity_decrease': 0.008724704592227944, 'max_features': 0.4673309369344586, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.006712216596772361}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:16,768] Finished trial#66 with value: 0.7927995034140286 with parameters: {'loss': 'exponential', 'learning_rate': 0.37316271671700146, 'n_estimators': 350, 'subsample': 0.4239927532322526, 'criterion': 'friedman_mse', 'min_samples_split': 64, 'min_samples_leaf': 29, 'max_depth': 15, 'min_impurity_decrease': 0.0156662780049006, 'max_features': 0.42276423593210033, 'max_leaf_nodes': 10, 'warm_start': True, 'n_iter_no_change': 20, 'ccp_alpha': 0.011750300760031807}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:17,651] Finished trial#67 with value: 0.8095096213531967 with parameters: {'loss': 'exponential', 'learning_rate': 0.37140706829267434, 'n_estimators': 371, 'subsample': 0.5631884961645952, 'criterion': 'friedman_mse', 'min_samples_split': 63, 'min_samples_leaf': 28, 'max_depth': 15, 'min_impurity_decrease': 0.013453524468166318, 'max_features': 0.44030126916857953, 'max_leaf_nodes': 10, 'warm_start': True, 'n_iter_no_change': 15, 'ccp_alpha': 0.012355914634700389}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:17,724] Finished trial#65 with value: 0.8139726877715704 with parameters: {'loss': 'exponential', 'learning_rate': 0.365473106288391, 'n_estimators': 363, 'subsample': 0.7408359993392004, 'criterion': 'friedman_mse', 'min_samples_split': 54, 'min_samples_leaf': 29, 'max_depth': 15, 'min_impurity_decrease': 0.012767636089992339, 'max_features': 0.41337593844408604, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': 20, 'ccp_alpha': 0.004667004799779824}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:18,617] Finished trial#68 with value: 0.8028429546865302 with parameters: {'loss': 'exponential', 'learning_rate': 0.2890273259349282, 'n_estimators': 270, 'subsample': 0.5692504762276173, 'criterion': 'friedman_mse', 'min_samples_split': 54, 'min_samples_leaf': 20, 'max_depth': 16, 'min_impurity_decrease': 0.029665184551601068, 'max_features': 0.2610334167670314, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': 15, 'ccp_alpha': 0.004507233341951176}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:19,096] Finished trial#59 with value: 0.8206765983860956 with parameters: {'loss': 'exponential', 'learning_rate': 0.2250832086756042, 'n_estimators': 315, 'subsample': 0.39768610642819513, 'criterion': 'friedman_mse', 'min_samples_split': 54, 'min_samples_leaf': 35, 'max_depth': 15, 'min_impurity_decrease': 0.021204733005566027, 'max_features': 0.5639349493416764, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.01656188294822328}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:19,892] Finished trial#70 with value: 0.8117939168218496 with parameters: {'loss': 'exponential', 'learning_rate': 0.28877267505586574, 'n_estimators': 473, 'subsample': 0.7389928011268954, 'criterion': 'friedman_mse', 'min_samples_split': 56, 'min_samples_leaf': 20, 'max_depth': 16, 'min_impurity_decrease': 0.012155032039783145, 'max_features': 0.38645269461747006, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': 20, 'ccp_alpha': 0.004102468145261411}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:20,290] Finished trial#69 with value: 0.8195654872749845 with parameters: {'loss': 'exponential', 'learning_rate': 0.28713496085535245, 'n_estimators': 430, 'subsample': 0.7253481738604239, 'criterion': 'friedman_mse', 'min_samples_split': 56, 'min_samples_leaf': 20, 'max_depth': 16, 'min_impurity_decrease': 0.02303274339341529, 'max_features': 0.26015303220934277, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': 20, 'ccp_alpha': 0.004267867438404876}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:20,669] Finished trial#71 with value: 0.803941651148355 with parameters: {'loss': 'exponential', 'learning_rate': 0.3918358669152261, 'n_estimators': 415, 'subsample': 0.732560955554453, 'criterion': 'friedman_mse', 'min_samples_split': 48, 'min_samples_leaf': 34, 'max_depth': 13, 'min_impurity_decrease': 0.02242655964794638, 'max_features': 0.5991700361197316, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': 20, 'ccp_alpha': 0.00021518423478733388}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:22,280] Finished trial#73 with value: 0.8140347610180013 with parameters: {'loss': 'exponential', 'learning_rate': 0.40135467068263475, 'n_estimators': 402, 'subsample': 0.8306118084426305, 'criterion': 'friedman_mse', 'min_samples_split': 48, 'min_samples_leaf': 35, 'max_depth': 13, 'min_impurity_decrease': 0.023269814486701124, 'max_features': 0.6075524054454472, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': 20, 'ccp_alpha': 0.0002822536661764427}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:22,339] Finished trial#72 with value: 0.7872253258845439 with parameters: {'loss': 'exponential', 'learning_rate': 0.2365636883053925, 'n_estimators': 359, 'subsample': 0.21738552251257398, 'criterion': 'friedman_mse', 'min_samples_split': 47, 'min_samples_leaf': 45, 'max_depth': 13, 'min_impurity_decrease': 0.02049443949382984, 'max_features': 0.5385099162994681, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': 20, 'ccp_alpha': 0.0007393116169019786}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:25,724] Finished trial#62 with value: 0.805046554934823 with parameters: {'loss': 'exponential', 'learning_rate': 0.36719784453267856, 'n_estimators': 359, 'subsample': 0.5642408982658895, 'criterion': 'friedman_mse', 'min_samples_split': 32, 'min_samples_leaf': 35, 'max_depth': 15, 'min_impurity_decrease': 0.02182306778840153, 'max_features': 0.43485589384807194, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.017415064124048543}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:25,793] Finished trial#61 with value: 0.8106207324643078 with parameters: {'loss': 'exponential', 'learning_rate': 0.37435504196742914, 'n_estimators': 366, 'subsample': 0.567879801891997, 'criterion': 'friedman_mse', 'min_samples_split': 52, 'min_samples_leaf': 37, 'max_depth': 15, 'min_impurity_decrease': 0.02166863738456874, 'max_features': 0.5441757686755475, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.016041474806802705}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:27,255] Finished trial#74 with value: 0.7694040968342645 with parameters: {'loss': 'exponential', 'learning_rate': 0.23546315098427928, 'n_estimators': 391, 'subsample': 0.42634134630479625, 'criterion': 'mae', 'min_samples_split': 48, 'min_samples_leaf': 45, 'max_depth': 13, 'min_impurity_decrease': 0.02087723853304818, 'max_features': 0.6011510314649493, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': 20, 'ccp_alpha': 0.00021930914001066538}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:27,457] Finished trial#77 with value: 0.7693792675356922 with parameters: {'loss': 'exponential', 'learning_rate': 0.1823427900923283, 'n_estimators': 114, 'subsample': 0.4286223215730594, 'criterion': 'mae', 'min_samples_split': 40, 'min_samples_leaf': 12, 'max_depth': 19, 'min_impurity_decrease': 0.0322604286735798, 'max_features': 0.25704278845280387, 'max_leaf_nodes': 100, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.014187104862052949}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:27,771] Finished trial#76 with value: 0.7882929857231533 with parameters: {'loss': 'exponential', 'learning_rate': 0.17946442154657707, 'n_estimators': 111, 'subsample': 0.43486082310707147, 'criterion': 'mae', 'min_samples_split': 19, 'min_samples_leaf': 13, 'max_depth': 18, 'min_impurity_decrease': 0.04042149939532019, 'max_features': 0.6691183518787054, 'max_leaf_nodes': 100, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.024129129715582506}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:29,081] Finished trial#63 with value: 0.8206269397889508 with parameters: {'loss': 'exponential', 'learning_rate': 0.37302150441973464, 'n_estimators': 354, 'subsample': 0.5690936837461867, 'criterion': 'friedman_mse', 'min_samples_split': 33, 'min_samples_leaf': 36, 'max_depth': 15, 'min_impurity_decrease': 0.02096585389242602, 'max_features': 0.4229247177011619, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.014417929712031105}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:29,355] Finished trial#75 with value: 0.7727684667908131 with parameters: {'loss': 'exponential', 'learning_rate': 0.16641933202289172, 'n_estimators': 400, 'subsample': 0.8213770355766691, 'criterion': 'mae', 'min_samples_split': 40, 'min_samples_leaf': 12, 'max_depth': 19, 'min_impurity_decrease': 0.024532903734185416, 'max_features': 0.533174018442078, 'max_leaf_nodes': 100, 'warm_start': True, 'n_iter_no_change': 20, 'ccp_alpha': 0.025145303894730773}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:29,419] Finished trial#80 with value: 0.7894413407821229 with parameters: {'loss': 'exponential', 'learning_rate': 0.4335737243276149, 'n_estimators': 425, 'subsample': 0.8222730292546216, 'criterion': 'mse', 'min_samples_split': 62, 'min_samples_leaf': 12, 'max_depth': 14, 'min_impurity_decrease': 0.025853401730034573, 'max_features': 0.6414274385979293, 'max_leaf_nodes': 100, 'warm_start': True, 'n_iter_no_change': 20, 'ccp_alpha': 0.010350614818879963}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:29,643] Finished trial#82 with value: 0.7883302296710119 with parameters: {'loss': 'exponential', 'learning_rate': 0.42564130197726036, 'n_estimators': 424, 'subsample': 0.8192620503447695, 'criterion': 'mse', 'min_samples_split': 63, 'min_samples_leaf': 20, 'max_depth': 11, 'min_impurity_decrease': 0.025587310980466165, 'max_features': 0.3102559909484717, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': 20, 'ccp_alpha': 0.011024343415038454}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:30,343] Finished trial#81 with value: 0.7861018001241467 with parameters: {'loss': 'exponential', 'learning_rate': 0.42208215026707474, 'n_estimators': 436, 'subsample': 0.8029610634126902, 'criterion': 'mse', 'min_samples_split': 61, 'min_samples_leaf': 54, 'max_depth': 11, 'min_impurity_decrease': 0.04066686871801471, 'max_features': 0.3163754701773836, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': 20, 'ccp_alpha': 0.010716716982000546}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:31,445] Finished trial#78 with value: 0.7805524518932341 with parameters: {'loss': 'exponential', 'learning_rate': 0.4199203387090166, 'n_estimators': 395, 'subsample': 0.8287933016728912, 'criterion': 'mae', 'min_samples_split': 40, 'min_samples_leaf': 12, 'max_depth': 19, 'min_impurity_decrease': 0.024806084484140716, 'max_features': 0.5970462303682573, 'max_leaf_nodes': 100, 'warm_start': True, 'n_iter_no_change': 20, 'ccp_alpha': 0.011748508404506443}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:32,168] Finished trial#87 with value: 0.7849844816883924 with parameters: {'loss': 'exponential', 'learning_rate': 0.3022245070046267, 'n_estimators': 67, 'subsample': 0.5045224470186482, 'criterion': 'friedman_mse', 'min_samples_split': 35, 'min_samples_leaf': 26, 'max_depth': 16, 'min_impurity_decrease': 0.015299130758900057, 'max_features': 0.36822049422046305, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': 10, 'ccp_alpha': 0.09503794869798074}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:32,744] Finished trial#79 with value: 0.7783550589695841 with parameters: {'loss': 'exponential', 'learning_rate': 0.4288650711076639, 'n_estimators': 482, 'subsample': 0.8247780619520325, 'criterion': 'mae', 'min_samples_split': 41, 'min_samples_leaf': 12, 'max_depth': 19, 'min_impurity_decrease': 0.02474242856791649, 'max_features': 0.6448961124501924, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': 20, 'ccp_alpha': 0.011105050280775177}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:32,916] Finished trial#88 with value: 0.8072998137802607 with parameters: {'loss': 'exponential', 'learning_rate': 0.3910452318575599, 'n_estimators': 385, 'subsample': 0.5179386672677461, 'criterion': 'friedman_mse', 'min_samples_split': 35, 'min_samples_leaf': 27, 'max_depth': 16, 'min_impurity_decrease': 0.028397236908908545, 'max_features': 0.3660703193363743, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': 10, 'ccp_alpha': 0.00445531288825414}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:35,281] Finished trial#64 with value: 0.8128677839851024 with parameters: {'loss': 'exponential', 'learning_rate': 0.3853361091588273, 'n_estimators': 366, 'subsample': 0.7462316048158099, 'criterion': 'friedman_mse', 'min_samples_split': 63, 'min_samples_leaf': 35, 'max_depth': 15, 'min_impurity_decrease': 0.021723437842975122, 'max_features': 0.4102504668268155, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.004799523026425627}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:39,430] Finished trial#83 with value: 0.7716573556797021 with parameters: {'loss': 'exponential', 'learning_rate': 0.3025211542129341, 'n_estimators': 336, 'subsample': 0.5085278818612999, 'criterion': 'mse', 'min_samples_split': 40, 'min_samples_leaf': 19, 'max_depth': 16, 'min_impurity_decrease': 0.026710809959326474, 'max_features': 0.36477018307159903, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.04809070530912203}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:44,534] Finished trial#85 with value: 0.8206828057107387 with parameters: {'loss': 'exponential', 'learning_rate': 0.30482695974098106, 'n_estimators': 337, 'subsample': 0.5056373017672788, 'criterion': 'friedman_mse', 'min_samples_split': 34, 'min_samples_leaf': 26, 'max_depth': 16, 'min_impurity_decrease': 0.028287327885776856, 'max_features': 0.36660552421407755, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.013929511773039856}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:44,598] Finished trial#84 with value: 0.8095468653010552 with parameters: {'loss': 'exponential', 'learning_rate': 0.3035617911267716, 'n_estimators': 334, 'subsample': 0.5094775397535186, 'criterion': 'friedman_mse', 'min_samples_split': 35, 'min_samples_leaf': 27, 'max_depth': 16, 'min_impurity_decrease': 0.02832859248954639, 'max_features': 0.3087633936558936, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.013036927977515437}. Best is trial#50 with value: 0.8229174425822471.
# [I 2020-05-23 11:13:45,743] Finished trial#91 with value: 0.7816511483550591 with parameters: {'loss': 'exponential', 'learning_rate': 0.4759457600790915, 'n_estimators': 332, 'subsample': 0.6249586178852847, 'criterion': 'friedman_mse', 'min_samples_split': 58, 'min_samples_leaf': 32, 'max_depth': 14, 'min_impurity_decrease': 0.01745784086164555, 'max_features': 0.408387772768536, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.05215666745756081}. Best is trial#50 with value: 0.8229174425822471.
# ...
# [I 2020-05-23 11:40:11,888] Finished trial#970 with value: 0.8184357541899441 with parameters: {'loss': 'exponential', 'learning_rate': 0.11187676246584491, 'n_estimators': 241, 'subsample': 0.9720018932532501, 'criterion': 'friedman_mse', 'min_samples_split': 66, 'min_samples_leaf': 10, 'max_depth': 7, 'min_impurity_decrease': 0.021170294545918424, 'max_features': 0.9160909115391626, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.0020067195330699264}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:12,380] Finished trial#974 with value: 0.8284667908131595 with parameters: {'loss': 'exponential', 'learning_rate': 0.11730603474292768, 'n_estimators': 241, 'subsample': 0.8352570245322054, 'criterion': 'friedman_mse', 'min_samples_split': 65, 'min_samples_leaf': 10, 'max_depth': 7, 'min_impurity_decrease': 0.05484588373413454, 'max_features': 0.22171492224850767, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.0015970872343066258}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:13,448] Finished trial#971 with value: 0.8206952203600248 with parameters: {'loss': 'exponential', 'learning_rate': 0.1169609962770156, 'n_estimators': 241, 'subsample': 0.8352897358145761, 'criterion': 'friedman_mse', 'min_samples_split': 64, 'min_samples_leaf': 11, 'max_depth': 7, 'min_impurity_decrease': 0.053570519507890935, 'max_features': 0.23019300533652254, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.0017204111085957728}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:13,534] Finished trial#969 with value: 0.8039168218497827 with parameters: {'loss': 'exponential', 'learning_rate': 0.11708070741734324, 'n_estimators': 272, 'subsample': 0.8284294805535768, 'criterion': 'friedman_mse', 'min_samples_split': 65, 'min_samples_leaf': 11, 'max_depth': 7, 'min_impurity_decrease': 0.05446369726626763, 'max_features': 0.22726352928830632, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.012263784260434648}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:13,597] Finished trial#976 with value: 0.821818746120422 with parameters: {'loss': 'exponential', 'learning_rate': 0.11486563658128036, 'n_estimators': 272, 'subsample': 0.8350005248750754, 'criterion': 'friedman_mse', 'min_samples_split': 64, 'min_samples_leaf': 10, 'max_depth': 7, 'min_impurity_decrease': 0.05459010880857886, 'max_features': 0.2268934763036053, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.002064975518443764}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:17,359] Finished trial#983 with value: 0.8240099317194289 with parameters: {'loss': 'exponential', 'learning_rate': 0.24803303673618615, 'n_estimators': 485, 'subsample': 0.7777180452859737, 'criterion': 'friedman_mse', 'min_samples_split': 57, 'min_samples_leaf': 6, 'max_depth': 5, 'min_impurity_decrease': 0.04967714086007965, 'max_features': 0.16904095975602437, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': 15, 'ccp_alpha': 5.494985682083595e-05}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:18,210] Finished trial#982 with value: 0.8162445685909374 with parameters: {'loss': 'exponential', 'learning_rate': 0.24860446634428018, 'n_estimators': 441, 'subsample': 0.7563854823485905, 'criterion': 'friedman_mse', 'min_samples_split': 57, 'min_samples_leaf': 6, 'max_depth': 11, 'min_impurity_decrease': 0.04970639823110001, 'max_features': 0.1640490925495381, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': 15, 'ccp_alpha': 0.005752651135022005}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:22,804] Finished trial#973 with value: 0.8262507759155804 with parameters: {'loss': 'exponential', 'learning_rate': 0.11256609359421534, 'n_estimators': 491, 'subsample': 0.9853651446649534, 'criterion': 'friedman_mse', 'min_samples_split': 64, 'min_samples_leaf': 11, 'max_depth': 7, 'min_impurity_decrease': 0.05446099440584609, 'max_features': 0.22606389701603036, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.0018511958611231937}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:26,608] Finished trial#978 with value: 0.8117628801986344 with parameters: {'loss': 'exponential', 'learning_rate': 0.24627519157368172, 'n_estimators': 269, 'subsample': 0.7747407340277921, 'criterion': 'friedman_mse', 'min_samples_split': 42, 'min_samples_leaf': 11, 'max_depth': 7, 'min_impurity_decrease': 0.051532795843488265, 'max_features': 0.2261918053345629, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.0016178666425783722}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:29,415] Finished trial#979 with value: 0.8162073246430788 with parameters: {'loss': 'exponential', 'learning_rate': 0.21180139617242819, 'n_estimators': 273, 'subsample': 0.43947631021425726, 'criterion': 'friedman_mse', 'min_samples_split': 57, 'min_samples_leaf': 6, 'max_depth': 7, 'min_impurity_decrease': 0.05051834269799808, 'max_features': 0.16162008680844436, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 4.968771612615412e-05}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:30,887] Finished trial#985 with value: 0.8151086281812538 with parameters: {'loss': 'exponential', 'learning_rate': 0.20684341435484407, 'n_estimators': 262, 'subsample': 0.2837691005125958, 'criterion': 'friedman_mse', 'min_samples_split': 55, 'min_samples_leaf': 4, 'max_depth': 5, 'min_impurity_decrease': 0.05157543292133206, 'max_features': 0.19596760217193143, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.006277844338735075}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:33,454] Finished trial#977 with value: 0.817324643078833 with parameters: {'loss': 'exponential', 'learning_rate': 0.11349382320574451, 'n_estimators': 270, 'subsample': 0.7221029033912956, 'criterion': 'friedman_mse', 'min_samples_split': 66, 'min_samples_leaf': 11, 'max_depth': 7, 'min_impurity_decrease': 0.02130355061000072, 'max_features': 0.22048948214219297, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 6.214456426419061e-05}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:34,368] Finished trial#981 with value: 0.7916697703289882 with parameters: {'loss': 'exponential', 'learning_rate': 0.24576846527998128, 'n_estimators': 450, 'subsample': 0.8923359251022882, 'criterion': 'friedman_mse', 'min_samples_split': 57, 'min_samples_leaf': 93, 'max_depth': 5, 'min_impurity_decrease': 0.0507133064479268, 'max_features': 0.1616015091215925, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.006298702309684377}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:36,426] Finished trial#980 with value: 0.8117628801986344 with parameters: {'loss': 'exponential', 'learning_rate': 0.21159696445175102, 'n_estimators': 448, 'subsample': 0.7557970947210536, 'criterion': 'friedman_mse', 'min_samples_split': 42, 'min_samples_leaf': 6, 'max_depth': 7, 'min_impurity_decrease': 0.050337844031635534, 'max_features': 0.5432360259260277, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.006746937094865949}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:37,245] Finished trial#989 with value: 0.8150837988826816 with parameters: {'loss': 'exponential', 'learning_rate': 0.14541958422771253, 'n_estimators': 295, 'subsample': 0.9019975087620286, 'criterion': 'friedman_mse', 'min_samples_split': 68, 'min_samples_leaf': 4, 'max_depth': 6, 'min_impurity_decrease': 0.04287861427523469, 'max_features': 0.27423891729424016, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': 20, 'ccp_alpha': 0.007082614807759888}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:37,612] Finished trial#990 with value: 0.8161949099937926 with parameters: {'loss': 'exponential', 'learning_rate': 0.15321065296390135, 'n_estimators': 293, 'subsample': 0.9523361232238728, 'criterion': 'friedman_mse', 'min_samples_split': 62, 'min_samples_leaf': 4, 'max_depth': 3, 'min_impurity_decrease': 0.04281821645025118, 'max_features': 0.53878587424424, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': 20, 'ccp_alpha': 0.006678875220945928}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:39,658] Finished trial#984 with value: 0.8150713842333953 with parameters: {'loss': 'exponential', 'learning_rate': 0.21247915411918417, 'n_estimators': 444, 'subsample': 0.8891154444269477, 'criterion': 'friedman_mse', 'min_samples_split': 58, 'min_samples_leaf': 5, 'max_depth': 11, 'min_impurity_decrease': 0.05116507785607511, 'max_features': 0.26646768397761156, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.006967717020909734}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:40,465] Finished trial#994 with value: 0.8061949099937926 with parameters: {'loss': 'exponential', 'learning_rate': 0.26157551675881313, 'n_estimators': 262, 'subsample': 0.799864505855767, 'criterion': 'friedman_mse', 'min_samples_split': 62, 'min_samples_leaf': 8, 'max_depth': 4, 'min_impurity_decrease': 0.04728368446278154, 'max_features': 0.2495623849820092, 'max_leaf_nodes': 10, 'warm_start': True, 'n_iter_no_change': 15, 'ccp_alpha': 0.003249451891149487}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:40,827] Finished trial#987 with value: 0.8150775915580384 with parameters: {'loss': 'exponential', 'learning_rate': 0.20694144821013988, 'n_estimators': 260, 'subsample': 0.895538976130954, 'criterion': 'friedman_mse', 'min_samples_split': 55, 'min_samples_leaf': 4, 'max_depth': 6, 'min_impurity_decrease': 0.04659730142738519, 'max_features': 0.1960291083234486, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.006458047620834821}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:42,141] Finished trial#991 with value: 0.8150900062073246 with parameters: {'loss': 'exponential', 'learning_rate': 0.153117779706486, 'n_estimators': 293, 'subsample': 0.9508094407371602, 'criterion': 'friedman_mse', 'min_samples_split': 58, 'min_samples_leaf': 4, 'max_depth': 4, 'min_impurity_decrease': 0.006963525127104115, 'max_features': 0.2681532728219204, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': 20, 'ccp_alpha': 0.003480978677128486}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:42,745] Finished trial#986 with value: 0.8184357541899441 with parameters: {'loss': 'exponential', 'learning_rate': 0.20764071156924804, 'n_estimators': 261, 'subsample': 0.8917997724986453, 'criterion': 'friedman_mse', 'min_samples_split': 42, 'min_samples_leaf': 4, 'max_depth': 6, 'min_impurity_decrease': 0.00727965411258492, 'max_features': 0.2929246693825007, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 1.0143304516235579e-05}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:43,675] Finished trial#993 with value: 0.8206517690875232 with parameters: {'loss': 'exponential', 'learning_rate': 0.12799311103289132, 'n_estimators': 264, 'subsample': 0.8762899341465423, 'criterion': 'friedman_mse', 'min_samples_split': 62, 'min_samples_leaf': 8, 'max_depth': 4, 'min_impurity_decrease': 0.04595997787783278, 'max_features': 0.24890535260204966, 'max_leaf_nodes': 10, 'warm_start': True, 'n_iter_no_change': 15, 'ccp_alpha': 0.003141978637044399}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:43,857] Finished trial#992 with value: 0.8229174425822471 with parameters: {'loss': 'exponential', 'learning_rate': 0.12588722040364972, 'n_estimators': 289, 'subsample': 0.9494944554541319, 'criterion': 'friedman_mse', 'min_samples_split': 62, 'min_samples_leaf': 4, 'max_depth': 4, 'min_impurity_decrease': 0.006763483639405773, 'max_features': 0.2765309930540018, 'max_leaf_nodes': None, 'warm_start': True, 'n_iter_no_change': 20, 'ccp_alpha': 5.099380323838102e-05}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:44,339] Finished trial#997 with value: 0.8150900062073246 with parameters: {'loss': 'exponential', 'learning_rate': 0.12788009278581586, 'n_estimators': 290, 'subsample': 0.8626853038347893, 'criterion': 'friedman_mse', 'min_samples_split': 62, 'min_samples_leaf': 2, 'max_depth': 5, 'min_impurity_decrease': 0.04548231722366076, 'max_features': 0.24917468937516335, 'max_leaf_nodes': 10, 'warm_start': True, 'n_iter_no_change': 5, 'ccp_alpha': 0.0036497133531592355}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:44,507] Finished trial#996 with value: 0.816213531967722 with parameters: {'loss': 'exponential', 'learning_rate': 0.12527231330760294, 'n_estimators': 291, 'subsample': 0.8662232677401084, 'criterion': 'friedman_mse', 'min_samples_split': 61, 'min_samples_leaf': 2, 'max_depth': 5, 'min_impurity_decrease': 0.04540617574050994, 'max_features': 0.24974770023698922, 'max_leaf_nodes': 10, 'warm_start': True, 'n_iter_no_change': 5, 'ccp_alpha': 0.0033932934046519043}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:44,573] Finished trial#988 with value: 0.8117442582247051 with parameters: {'loss': 'exponential', 'learning_rate': 0.2055110639405736, 'n_estimators': 261, 'subsample': 0.8935534985930914, 'criterion': 'friedman_mse', 'min_samples_split': 61, 'min_samples_leaf': 4, 'max_depth': 6, 'min_impurity_decrease': 0.04549815091850235, 'max_features': 0.2703229418258608, 'max_leaf_nodes': 50, 'warm_start': True, 'n_iter_no_change': None, 'ccp_alpha': 0.006491011310671501}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:44,966] Finished trial#998 with value: 0.8228988206083179 with parameters: {'loss': 'exponential', 'learning_rate': 0.12465056906986176, 'n_estimators': 434, 'subsample': 0.8603103541380814, 'criterion': 'friedman_mse', 'min_samples_split': 61, 'min_samples_leaf': 2, 'max_depth': 6, 'min_impurity_decrease': 0.04485629995301534, 'max_features': 0.24552500591293952, 'max_leaf_nodes': 10, 'warm_start': False, 'n_iter_no_change': 15, 'ccp_alpha': 0.003411597845211672}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:44,967] Finished trial#999 with value: 0.8295779019242706 with parameters: {'loss': 'exponential', 'learning_rate': 0.1278232539640698, 'n_estimators': 434, 'subsample': 0.8606447677781959, 'criterion': 'friedman_mse', 'min_samples_split': 67, 'min_samples_leaf': 7, 'max_depth': 6, 'min_impurity_decrease': 0.045481008307896725, 'max_features': 0.20774183336466995, 'max_leaf_nodes': 10, 'warm_start': False, 'n_iter_no_change': 5, 'ccp_alpha': 9.672216765246487e-05}. Best is trial#855 with value: 0.8384978274363748.
# [I 2020-05-23 11:40:44,967] Finished trial#995 with value: 0.8117504655493482 with parameters: {'loss': 'exponential', 'learning_rate': 0.12711289138616003, 'n_estimators': 262, 'subsample': 0.8587856722912804, 'criterion': 'friedman_mse', 'min_samples_split': 61, 'min_samples_leaf': 8, 'max_depth': 4, 'min_impurity_decrease': 0.0074618214307707416, 'max_features': 0.24898194382542008, 'max_leaf_nodes': 10, 'warm_start': True, 'n_iter_no_change': 15, 'ccp_alpha': 0.0031167078713365648}. Best is trial#855 with value: 0.8384978274363748.

# %%
# top scores
opt_scores = study.trials_dataframe()
opt_scores.sort_values("value", ascending=False).head(5)
# Out:
#      number     value             datetime_start          datetime_complete  \
# 855     855  0.838498 2020-05-23 11:36:54.483628 2020-05-23 11:37:11.231312
# 633     633  0.837381 2020-05-23 11:31:34.811221 2020-05-23 11:31:47.869487
# 881     881  0.837381 2020-05-23 11:37:41.433996 2020-05-23 11:37:46.324966
# 585     585  0.836263 2020-05-23 11:29:45.681070 2020-05-23 11:30:01.943173
# 626     626  0.836245 2020-05-23 11:31:05.664580 2020-05-23 11:31:17.893098
#
#      params_ccp_alpha params_criterion  params_learning_rate  params_loss  \
# 855          0.002012     friedman_mse              0.205729  exponential
# 633          0.002021     friedman_mse              0.154209  exponential
# 881          0.000063     friedman_mse              0.104712  exponential
# 585          0.001715     friedman_mse              0.131936  exponential
# 626          0.002023     friedman_mse              0.155867  exponential
#
#      params_max_depth  params_max_features  params_max_leaf_nodes  \
# 855                 6             0.176569                   50.0
# 633                 6             0.199037                   50.0
# 881                 5             0.654077                   50.0
# 585                 8             0.245116                   50.0
# 626                 6             0.224050                   50.0
#
#      params_min_impurity_decrease  params_min_samples_leaf  \
# 855                      0.006195                        7
# 633                      0.049801                        2
# 881                      0.049314                        2
# 585                      0.048871                        5
# 626                      0.049565                        2
#
#      params_min_samples_split  params_n_estimators  params_n_iter_no_change  \
# 855                         3                  302                      NaN
# 633                        64                  254                      NaN
# 881                        61                  280                     15.0
# 585                        50                  300                      NaN
# 626                        63                  274                      NaN
#
#      params_subsample  params_warm_start     state
# 855          0.963744               True  COMPLETE
# 633          0.955405               True  COMPLETE
# 881          0.918787               True  COMPLETE
# 585          0.865442               True  COMPLETE
# 626          0.848081               True  COMPLETE

# %%
import re
top_params = {}
for x in range(0, 5): 
    params = dict(opt_scores.sort_values("value", ascending=False).iloc[x,4:-1])
    params = {re.sub('params_', '', key): val for key, val in params.items()}
    top_params[x] = params

# %%
for x in range(0,5):
    print(top_params[x])
# Out:
# {'ccp_alpha': 0.0020121368398624364, 'criterion': 'friedman_mse', 'learning_rate': 0.20572877787819044, 'loss': 'exponential', 'max_depth': 6, 'max_features': 0.17656921450338955, 'max_leaf_nodes': 50.0, 'min_impurity_decrease': 0.0061954301244089805, 'min_samples_leaf': 7, 'min_samples_split': 3, 'n_estimators': 302, 'n_iter_no_change': nan, 'subsample': 0.963743813416333, 'warm_start': True}
# {'ccp_alpha': 0.002020800985339463, 'criterion': 'friedman_mse', 'learning_rate': 0.1542088308919397, 'loss': 'exponential', 'max_depth': 6, 'max_features': 0.19903695658492065, 'max_leaf_nodes': 50.0, 'min_impurity_decrease': 0.049800610940764156, 'min_samples_leaf': 2, 'min_samples_split': 64, 'n_estimators': 254, 'n_iter_no_change': nan, 'subsample': 0.955404624588575, 'warm_start': True}
# {'ccp_alpha': 6.287427032653941e-05, 'criterion': 'friedman_mse', 'learning_rate': 0.10471245666478986, 'loss': 'exponential', 'max_depth': 5, 'max_features': 0.6540767795374985, 'max_leaf_nodes': 50.0, 'min_impurity_decrease': 0.04931444639079484, 'min_samples_leaf': 2, 'min_samples_split': 61, 'n_estimators': 280, 'n_iter_no_change': 15.0, 'subsample': 0.9187871136612589, 'warm_start': True}
# {'ccp_alpha': 0.001715108495987478, 'criterion': 'friedman_mse', 'learning_rate': 0.13193638859464804, 'loss': 'exponential', 'max_depth': 8, 'max_features': 0.2451162605347299, 'max_leaf_nodes': 50.0, 'min_impurity_decrease': 0.04887063973387433, 'min_samples_leaf': 5, 'min_samples_split': 50, 'n_estimators': 300, 'n_iter_no_change': nan, 'subsample': 0.8654418656799914, 'warm_start': True}
# {'ccp_alpha': 0.0020227602704888242, 'criterion': 'friedman_mse', 'learning_rate': 0.1558669429393742, 'loss': 'exponential', 'max_depth': 6, 'max_features': 0.2240499917797328, 'max_leaf_nodes': 50.0, 'min_impurity_decrease': 0.049564577308527605, 'min_samples_leaf': 2, 'min_samples_split': 63, 'n_estimators': 274, 'n_iter_no_change': nan, 'subsample': 0.8480812470625199, 'warm_start': True}

# %%
from sklearn.ensemble import VotingClassifier

# %%
gb1 = GradientBoostingClassifier(**{'ccp_alpha': 0.0020121368398624364, 
                                   'criterion': 'friedman_mse', 
                                   'learning_rate': 0.20572877787819044, 
                                   'loss': 'exponential', 'max_depth': 6, 
                                   'max_features': 0.17656921450338955, 
                                   'max_leaf_nodes': 50, 
                                   'min_impurity_decrease': 0.0061954301244089805, 
                                   'min_samples_leaf': 7, 'min_samples_split': 3, 
                                   'subsample': 0.963743813416333, 
                                   'warm_start': True}, random_state = 1234, validation_fraction = 0.2)
gb2 = GradientBoostingClassifier(**{'ccp_alpha': 0.002020800985339463, 
                                     'criterion': 'friedman_mse', 
                                     'learning_rate': 0.1542088308919397, 
                                     'loss': 'exponential', 
                                     'max_depth': 6, 
                                     'max_features': 0.19903695658492065,
                                     'max_leaf_nodes': 50, 
                                     'min_impurity_decrease': 0.049800610940764156, 
                                     'min_samples_leaf': 2, 
                                     'min_samples_split': 64, 
                                     'n_estimators': 254, 
                                     'subsample': 0.955404624588575, 
                                     'warm_start': True}, random_state = 1234, validation_fraction = 0.2)
gb3 = GradientBoostingClassifier(**{'ccp_alpha': 6.287427032653941e-05,
                                     'criterion': 'friedman_mse', 
                                     'learning_rate': 0.10471245666478986,
                                     'loss': 'exponential', 'max_depth': 5,
                                     'max_features': 0.6540767795374985,
                                     'max_leaf_nodes': 50,
                                     'min_impurity_decrease': 0.04931444639079484,
                                     'min_samples_leaf': 2, 
                                     'min_samples_split': 61,
                                     'n_estimators': 280, 
                                     'n_iter_no_change': 15, 
                                     'subsample': 0.9187871136612589, 
                                     'warm_start': True}, random_state = 1234, validation_fraction = 0.2)
gb4 = GradientBoostingClassifier(**{'ccp_alpha': 0.001715108495987478,
                                     'criterion': 'friedman_mse', 
                                     'learning_rate': 0.13193638859464804, 
                                     'loss': 'exponential', 'max_depth': 8, 
                                     'max_features': 0.2451162605347299,
                                     'max_leaf_nodes': 50,
                                     'min_impurity_decrease': 0.04887063973387433,
                                     'min_samples_leaf': 5, 
                                     'min_samples_split': 50,
                                     'n_estimators': 300, 
                                     'subsample': 0.8654418656799914, 
                                     'warm_start': True}, random_state = 1234, validation_fraction = 0.2)
gb5 = GradientBoostingClassifier(**{'ccp_alpha': 0.0020227602704888242,
                                     'criterion': 'friedman_mse', 
                                     'learning_rate': 0.1558669429393742,
                                     'loss': 'exponential', 'max_depth': 6,
                                     'max_features': 0.2240499917797328, 'max_leaf_nodes': 50,
                                     'min_impurity_decrease': 0.049564577308527605,
                                     'min_samples_leaf': 2, 'min_samples_split': 63,
                                     'n_estimators': 274,
                                     'subsample': 0.8480812470625199, 
                                     'warm_start': True}, random_state = 1234, validation_fraction = 0.2)
estimators = []
estimators.append(('gb1', gb1))
estimators.append(('gb2', gb2))
estimators.append(('gb3', gb3))
estimators.append(('gb4', gb4))
estimators.append(('gb5', gb5))

# %%
voting_model = VotingClassifier(estimators = estimators, voting = 'soft', n_jobs = -1)

# %%
cross_val_score(voting_model, train_set, target, n_jobs=-1, cv=5, scoring = 'accuracy').mean()
# Out:
# 0.8362693978895095

# %% [markdown]
# ### Step 4: Run model

# %%
model = Model(model     = voting_model,              # Initialized classifier model from SKLearn
            #  variables = selected_variables_SVC, # Subset of variables from data to be used for training
                                                  # If variables=None, then all variables in set are used
              
              train_set = train_set,              # Samples X for training and validating
              target    = target,                 # Samples Y for training and validating
              test_set  = test_set                # Unlabeled samples for creating prediction
              )                 

model.run_model(path="results/votingEns_results.csv")
# Out:
# Model - VotingClassifier(estimators=[('gb1',
#                               GradientBoostingClassifier(ccp_alpha=0.0020121368398624364,
#                                                          criterion='friedman_mse',
#                                                          init=None,
#                                                          learning_rate=0.20572877787819044,
#                                                          loss='exponential',
#                                                          max_depth=6,
#                                                          max_features=0.17656921450338955,
#                                                          max_leaf_nodes=50,
#                                                          min_impurity_decrease=0.0061954301244089805,
#                                                          min_impurity_split=None,
#                                                          min_samples_leaf=7,
#                                                          min_samples_split...
#                                                          min_impurity_decrease=0.049564577308527605,
#                                                          min_impurity_split=None,
#                                                          min_samples_leaf=2,
#                                                          min_samples_split=63,
#                                                          min_weight_fraction_leaf=0.0,
#                                                          n_estimators=274,
#                                                          n_iter_no_change=None,
#                                                          presort='deprecated',
#                                                          random_state=1234,
#                                                          subsample=0.8480812470625199,
#                                                          tol=0.0001,
#                                                          validation_fraction=0.2,
#                                                          verbose=0,
#                                                          warm_start=True))],
#                  flatten_transform=True, n_jobs=-1, voting='soft',
#                  weights=None)
# Average model accuracy: 82.62%
# Highest model accuracy: 85.00%
# Solution set saved as 'results/votingEns_results.csv'.

# %% [markdown]
# **kaggle result: 0.82500**
